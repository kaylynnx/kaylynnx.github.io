# %%
import numpy as np
from matplotlib import pyplot as plt

def pad(X):
    return np.append(X, np.ones((X.shape[0], 1)), 1)

def LR_data(n_train = 100, n_val = 100, p_features = 1, noise = .1, w = None):
    if w is None: 
        w = np.random.rand(p_features + 1) + .2
    
    X_train = np.random.rand(n_train, p_features)
    y_train = pad(X_train)@w + noise*np.random.randn(n_train)

    X_val = np.random.rand(n_val, p_features)
    y_val = pad(X_val)@w + noise*np.random.randn(n_val)
    
    return X_train, y_train, X_val, y_val

# %%
n_train = 100
n_val = 100
p_features = 1
noise = 0.2

# create some data
X_train, y_train, X_val, y_val = LR_data(n_train, n_val, p_features, noise)

# plot it
fig, axarr = plt.subplots(1, 2, sharex = True, sharey = True)
axarr[0].scatter(X_train, y_train)
axarr[1].scatter(X_val, y_val)
labs = axarr[0].set(title = "Training", xlabel = "x", ylabel = "y")
labs = axarr[1].set(title = "Validation", xlabel = "x")
plt.tight_layout()

# %%
class LinearRegression:
    def __init__(self):
        self.w = None
        self.score_history = []
    
    def pad(self, X):
        return np.append(X, np.ones((X.shape[0], 1)), 1)
    
    def fit_analytic(self, X, y):
        X = self.pad(X)
        self.w = np.linalg.inv(X.T @ X) @ X.T @ y
    
    def fit_gradient(self, X, y, alpha, max_iter):
        n, p = X.shape
        self.w = np.random.randn(p)
        XT_X = X.T @ X
        XT_y = X.T @ y
        for _ in range(max_iter):
            y_pred = self.predict(X)
            self.w -= alpha * (XT_X @ self.w - XT_y)
            self.score_history.append(self.score(X, y))
            
    def predict(self, X):
        X = self.pad(X)
        return X @ self.w
    
    def score(self, X, y):
        y_pred = self.predict(X)
        ssr = np.sum((y_pred - y.mean())**2)
        sst = np.sum((y - y.mean())**2)
        return ssr / sst

# %%
LR = LinearRegression()
LR.fit_analytic(X_train, y_train) # I used the analytical formula as my default fit method

print(f"Training score = {LR.score(X_train, y_train).round(4)}")
print(f"Validation score = {LR.score(X_val, y_val).round(4)}")
# Out:
# Training score = 0.4972
# Validation score = 0.591

# %%
LR2 = LinearRegression()

LR2.fit_gradient(X_train, y_train, alpha = 0.01, max_iter = 1e2)
LR2.w
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/k5/sv5thph578dff6sqh3h3z2kw0000gn/T/ipykernel_27969/1280909469.py in <module>
#       1 LR2 = LinearRegression()
#       2
# ----> 3 LR2.fit_gradient(X_train, y_train, alpha = 0.01, max_iter = 1e2)
#       4 LR2.w
#
# /var/folders/k5/sv5thph578dff6sqh3h3z2kw0000gn/T/ipykernel_27969/2315860588.py in fit_gradient(self, X, y, alpha, max_iter)
#      16         XT_X = X.T @ X
#      17         XT_y = X.T @ y
# ---> 18         for _ in range(max_iter):
#      19             y_pred = self.predict(X)
#      20             self.w -= alpha * (XT_X @ self.w - XT_y)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
plt.plot(LR2.score(X_train, y_train))
labels = plt.gca().set(xlabel = "Iteration", ylabel = "Score")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/k5/sv5thph578dff6sqh3h3z2kw0000gn/T/ipykernel_27969/866310384.py in <module>
# ----> 1 plt.plot(LR2.score(X_train, y_train))
#       2 labels = plt.gca().set(xlabel = "Iteration", ylabel = "Score")
#
# /var/folders/k5/sv5thph578dff6sqh3h3z2kw0000gn/T/ipykernel_27969/2315860588.py in score(self, X, y)
#      26
#      27     def score(self, X, y):
# ---> 28         y_pred = self.predict(X)
#      29         ssr = np.sum((y_pred - y.mean())**2)
#      30         sst = np.sum((y - y.mean())**2)
#
# /var/folders/k5/sv5thph578dff6sqh3h3z2kw0000gn/T/ipykernel_27969/2315860588.py in predict(self, X)
#      23     def predict(self, X):
#      24         X = self.pad(X)
# ---> 25         return X @ self.w
#      26
#      27     def score(self, X, y):
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 1 is different from 2)
